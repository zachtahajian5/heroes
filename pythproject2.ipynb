# %% [markdown]
# <a href="https://colab.research.google.com/github/zachtahajian5/heroes/blob/main/pythproject2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import unittest

class Overwatch:
  def __init__(self):
    pass

class OverwatchMaps(Overwatch):
  pass
class OverwatchHeroes(Overwatch):
  _hero_id = 1
  def __init__(self, hero_name):
    self.hero_name = hero_name
    self.character_id = None
    self.dps = None
  def damage_per_second(self, dps):
    self.dps = dps
  def assign_hero_id(self):
    if self.character_id is not None:
      raise ValueError("Hero ID is already assigned!")
    self.character_id = OverwatchHeroes._hero_id
    OverwatchHeroes._hero_id += 1
    return self.character_id
#returning hero instance as a string now
  def __str__(self):
    return f"Hero name is {self.hero_name}, Hero id is {self.character_id}, They deal {self.dps} damage per second."

ow_heroes_dps = {
    # TANK
    "D.Va": 146,
    "Doomfist": 73.3,
    "Hazard": 131.58,
    "Junker Queen": 106,
    "Mauga": 72,
    "Orisa": 99.42,
    "Ramattra": 125,
    "Reinhardt": 104,
    "Roadhog": 200,
    "Sigma": 73.3,
    "Winston": 70,
    "Wrecking Ball": 125,
    "Zarya": 95,            # 0 % energy beam; max is 190

    # DAMAGE
    "Ashe": 136.5,
    "Bastion": 125,         # Recon mode; Assault mode is 360
    "Cassidy": 416.67,
    "Echo": 151.79,
    "Genji": 92,
    "Hanzo": 96.15,         # fully‑drawn Storm Bow
    "Junkrat": 180,
    "Mei": 100,
    "Pharah": 150,
    "Reaper": 216,
    "Sojourn": 135,
    "Soldier: 76": 171,
    "Sombra": 160,
    "Symmetra": 180,        # level‑3 Photon Projector beam
    "Torbjörn": 137.25,
    "Tracer": 240,          # Pulse Pistols (see note)
    "Widowmaker": 130,      # unscoped auto‑fire (see note)

    # SUPPORT
    "Ana": 83,              # Biotic Rifle (see note)
    "Baptiste": 100,        # Biotic Launcher (see note)
    "Brigitte": 57,         # Rocket Flail (see note)
    "Illari": 105,          # Solar Rifle primary beam (see note)
    "Kiriko": 156,          # Kunai rate‑of‑fire DPS (see note)
    "Lifeweaver": 37.5,     # Thorn Volley (see note)
    "Lúcio": 95.04,
    "Mercy": 50,            # Caduceus Blaster (see note)
    "Moira": 50,            # Biotic Grasp primary (see note)
    "Zenyatta": 120
}

print(dir(ow_heroes_dps))
#we'll build another dictionary from the Overwatch fan site: https://overwatch.fandom.com/wiki/Heroes

#we can unpack these items with the .items() function to create a list

list_ow_heroes_dps = list(ow_heroes_dps.items())

Sombra = OverwatchHeroes("Sombra")
Sombra.damage_per_second(200)
Sombra.assign_hero_id()
print(Sombra)
Zarya = OverwatchHeroes("Zarya")
Zarya.damage_per_second(300)
Zarya.assign_hero_id()
print(Zarya)
# Out:
# ['__class__', '__class_getitem__', '__contains__', '__delattr__', '__delitem__', '__dir__', '__doc__', '__eq__', '__format__', '__ge__', '__getattribute__', '__getitem__', '__getstate__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__ior__', '__iter__', '__le__', '__len__', '__lt__', '__ne__', '__new__', '__or__', '__reduce__', '__reduce_ex__', '__repr__', '__reversed__', '__ror__', '__setattr__', '__setitem__', '__sizeof__', '__str__', '__subclasshook__', 'clear', 'copy', 'fromkeys', 'get', 'items', 'keys', 'pop', 'popitem', 'setdefault', 'update', 'values']
# Hero name is Sombra, Hero id is 1, They deal 200 damage per second.
# Hero name is Zarya, Hero id is 2, They deal 300 damage per second.

# %%
import unittest

class Overwatch:
  def __init__(self):
    pass

class OverwatchMaps(Overwatch):
  pass
class OverwatchHeroes(Overwatch):
  # _hero_id = 1
  def __init__(self, hero_stats):
   self.hero_stats = hero_stats
   print(dir(object))
  def print_and_return_heroes_list(self):
    for hero, dps in self.hero_stats:
      print(f"{hero} deals {dps} DPS under optimal conditions.")
    return self.hero_stats
#returning hero instance as a string now
  # def __str__(self):
  #   return f"Hero name is {self.hero_name}, Hero id is {self.character_id}, They deal {self.dps} damage per second."


ow_heroes_dps = {
    # TANK
    "D.Va": 146,
    "Doomfist": 73.3,
    "Hazard": 131.58,
    "Junker Queen": 106,
    "Mauga": 72,
    "Orisa": 99.42,
    "Ramattra": 125,
    "Reinhardt": 104,
    "Roadhog": 200,
    "Sigma": 73.3,
    "Winston": 70,
    "Wrecking Ball": 125,
    "Zarya": 95,            # 0 % energy beam; max is 190

    # DAMAGE
    "Ashe": 136.5,
    "Bastion": 125,         # Recon mode; Assault mode is 360
    "Cassidy": 416.67,
    "Echo": 151.79,
    "Genji": 92,
    "Hanzo": 96.15,         # fully‑drawn Storm Bow
    "Junkrat": 180,
    "Mei": 100,
    "Pharah": 150,
    "Reaper": 216,
    "Sojourn": 135,
    "Soldier: 76": 171,
    "Sombra": 160,
    "Symmetra": 180,        # level‑3 Photon Projector beam
    "Torbjörn": 137.25,
    "Tracer": 240,          # Pulse Pistols (see note)
    "Widowmaker": 130,      # unscoped auto‑fire (see note)

    # SUPPORT
    "Ana": 83,              # Biotic Rifle (see note)
    "Baptiste": 100,        # Biotic Launcher (see note)
    "Brigitte": 57,         # Rocket Flail (see note)
    "Illari": 105,          # Solar Rifle primary beam (see note)
    "Kiriko": 156,          # Kunai rate‑of‑fire DPS (see note)
    "Lifeweaver": 37.5,     # Thorn Volley (see note)
    "Lúcio": 95.04,
    "Mercy": 50,            # Caduceus Blaster (see note)
    "Moira": 50,            # Biotic Grasp primary (see note)
    "Zenyatta": 120
}

list_ow_heroes_dps = list(ow_heroes_dps.items())

roster = OverwatchHeroes(list_ow_heroes_dps)
roster.print_and_return_heroes_list()
# Out:
# ['__class__', '__delattr__', '__dir__', '__doc__', '__eq__', '__format__', '__ge__', '__getattribute__', '__getstate__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__le__', '__lt__', '__ne__', '__new__', '__reduce__', '__reduce_ex__', '__repr__', '__setattr__', '__sizeof__', '__str__', '__subclasshook__']
# D.Va deals 146 DPS under optimal conditions.
# Doomfist deals 73.3 DPS under optimal conditions.
# Hazard deals 131.58 DPS under optimal conditions.
# Junker Queen deals 106 DPS under optimal conditions.
# Mauga deals 72 DPS under optimal conditions.
# Orisa deals 99.42 DPS under optimal conditions.
# Ramattra deals 125 DPS under optimal conditions.
# Reinhardt deals 104 DPS under optimal conditions.
# Roadhog deals 200 DPS under optimal conditions.
# Sigma deals 73.3 DPS under optimal conditions.
# Winston deals 70 DPS under optimal conditions.
# Wrecking Ball deals 125 DPS under optimal conditions.
# Zarya deals 95 DPS under optimal conditions.
# ...
